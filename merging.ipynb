# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('merged_result1.csv',encoding = 'unicode_escape')

# %%
df1.head()
# Out:
#    Unnamed: 0                                            content  \
# 0           0  ['Gara2 video ini nih yang bikin gue nggak sab...
# 1           1  ['@ cakefacee_xo hahaha I love this! Have you ...
# 2           2  ['Camren Bicondova attends the 'Batman V Super...
# 3           3  ['THE HOBBIT THE BATTLE OF THE FIVE ARMIES (20...
# 4           4  ['Cinema, # teamcap # TeamIronMan # TeamTodoMu...
#
#                                        Movie   Startdate     Enddate
# 0                                    Spectre  2015/10/23  2015/10/29
# 1                    Avengers: Age of Ultron   2015/4/19   2015/4/25
# 2         Batman v Superman: Dawn of Justice   2016/3/20   2016/3/26
# 3  The Hobbit: The Battle of the Five Armies   2014/12/7  2014/12/13
# 4                 Captain America: Civil War   2016/4/24   2016/4/30

# %%
df2 = pd.read_csv('merged_data_innerJoin.csv',encoding = 'unicode_escape')

# %%
df2.head()
# Out:
#                                  movie_title  color  director_name  \
# 0                                    Spectre  Color     Sam Mendes
# 1                    Avengers: Age of Ultron  Color    Joss Whedon
# 2         Batman v Superman: Dawn of Justice  Color    Zack Snyder
# 3  The Hobbit: The Battle of the Five Armies  Color  Peter Jackson
# 4                 Captain America: Civil War  Color  Anthony Russo
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   602.0     148.0                        0
# 1                   635.0     141.0                        0
# 2                   673.0     183.0                        0
# 3                   422.0     164.0                        0
# 4                   516.0     147.0                       94
#
#    actor_3_facebook_likes        actor_2_name  actor_1_facebook_likes  \
# 0                   161.0        Rory Kinnear                   11000
# ...

# %%
df2.columns
# Out:
# Index(['movie_title', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres_x',
#        'actor_1_name', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget_x', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'budget_y',
#        'genres_y', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'Startdate', 'Enddate', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df = df1.merge(df2, left_on='Movie', right_on='movie_title')

# %%
df
# Out:
#      Unnamed: 0                                            content  \
# 0             0  ['Gara2 video ini nih yang bikin gue nggak sab...
# 1             1  ['@ cakefacee_xo hahaha I love this! Have you ...
# 2             2  ['Camren Bicondova attends the 'Batman V Super...
# 3             3  ['THE HOBBIT THE BATTLE OF THE FIVE ARMIES (20...
# 4             4  ['Cinema, # teamcap # TeamIronMan # TeamTodoMu...
# 5             6  ['Transformers: Age of Extinction movie premie...
# 6             7  ['The Amazing Spider-Man 2â²s # Xbox One rele...
# 7             8  ['Furious 7 gave me the feelsI wanna watch fur...
# 8             9  ['Click here to # win a prize bundle from X-me...
# 9            10  ['âInside Outâ?Easter Eggs Give Shoutouts t...
# 10           11  ['âI want @ DorkShelf to send me to # StarTr...
# 11           12  ['(= para el estrÃ©s ! (@CinÃ©polis for X-Men:...
# 12           13  ['watching Suicide Squad at Emagine Theatres h...
# ...

# %%
df.to_csv('mergingfile.csv')

# %%
df3 = pd.read_csv('sentimentresult.csv')

# %%
df3
# Out:
#      Unnamed: 0                                               text  score  \
# 0             0  ['Gara2 video ini nih yang bikin gue nggak sab...    0.1
# 1             1  ['@ cakefacee_xo hahaha I love this! Have you ...    0.2
# 2             2  ['Camren Bicondova attends the 'Batman V Super...    0.1
# 3             3  ['THE HOBBIT THE BATTLE OF THE FIVE ARMIES (20...    0.4
# 4             4  ['Cinema, # teamcap # TeamIronMan # TeamTodoMu...    0.4
# 5             5  ['Transformers: Age of Extinction movie premie...    0.4
# 6             6  ['The Amazing Spider-Man 2â²s # Xbox One rele...    0.7
# 7             7  ['Furious 7 gave me the feelsI wanna watch fur...    0.2
# 8             8  ['Click here to # win a prize bundle from X-me...    0.2
# 9             9  ['âInside Outâ?Easter Eggs Give Shoutouts t...    0.7
# 10           10  ['âI want @ DorkShelf to send me to # StarTr...    0.2
# 11           11  ['(= para el estrÃ©s ! (@CinÃ©polis for X-Men:...    0.3
# ...

# %%
final_df = df.merge(df3, left_on='Movie', right_on='Movie')

# %%
final_df
# Out:
#      Unnamed: 0_x                                            content  \
# 0               0  ['Gara2 video ini nih yang bikin gue nggak sab...
# 1               1  ['@ cakefacee_xo hahaha I love this! Have you ...
# 2               2  ['Camren Bicondova attends the 'Batman V Super...
# 3               3  ['THE HOBBIT THE BATTLE OF THE FIVE ARMIES (20...
# 4               4  ['Cinema, # teamcap # TeamIronMan # TeamTodoMu...
# 5               6  ['Transformers: Age of Extinction movie premie...
# 6               7  ['The Amazing Spider-Man 2â²s # Xbox One rele...
# 7               8  ['Furious 7 gave me the feelsI wanna watch fur...
# 8               9  ['Click here to # win a prize bundle from X-me...
# 9              10  ['âInside Outâ?Easter Eggs Give Shoutouts t...
# 10             11  ['âI want @ DorkShelf to send me to # StarTr...
# 11             12  ['(= para el estrÃ©s ! (@CinÃ©polis for X-Men:...
# 12             13  ['watching Suicide Squad at Emagine Theatres h...
# ...

# %%
final_df.to_csv('mergingfile.csv')

# %%
df4 = pd.read_csv('twitter_bag_final.csv')

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'content', 'Movie', 'Startdate',
#        'Enddate', 'age', 'america', 'back', 'bad',
#        ...
#        'well', 'win', 'winter', 'woman', 'world', 'would', 'www', 'year',
#        'youtu', 'youtube'],
#       dtype='object', length=156)

# %%
df_result = final_df.merge(df4, left_on='Movie', right_on='Movie')

# %%
df_result.columns
# Out:
# Index(['Unnamed: 0_x', 'content_x', 'Movie', 'Startdate_x', 'Enddate_x',
#        'movie_title', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration',
#        ...
#        'well', 'win', 'winter', 'woman', 'world', 'would', 'www', 'year',
#        'youtu', 'youtube'],
#       dtype='object', length=214)

# %%
df_result.to_csv('finalmergingfile.csv')
